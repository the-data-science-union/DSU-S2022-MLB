# %%
import numpy as np
import pandas as pd

# %%
relief = pd.read_csv('ReliefPitching.csv', float_precision = 'round_trip')
relief.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5f3b99cc98d6> in <module>()
# ----> 1 relief = pd.read_csv('ReliefPitching.csv', float_precision = 'round_trip')
#       2 relief.info()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
relief.drop('1stIP', axis = 1, inplace = True)
relief.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 32 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     660 non-null    int64
#  1   Tm       660 non-null    object
#  2   G        660 non-null    int64
#  3   GR       660 non-null    int64
#  4   GF       660 non-null    int64
#  5   Wgr      660 non-null    int64
#  6   Lgr      660 non-null    int64
#  7   SVOpp    660 non-null    int64
#  8   SV       660 non-null    int64
#  9   BSv      660 non-null    int64
#  10  SV%      660 non-null    object
#  11  SVSit    660 non-null    int64
#  12  Hold     660 non-null    int64
#  13  IR       660 non-null    int64
#  14  IS       660 non-null    int64
#  15  IS%      660 non-null    object
#  16  aLI      660 non-null    float64
#  17  LevHi    660 non-null    int64
#  18  LevMd    660 non-null    int64
#  19  LevLo    660 non-null    int64
#  20  Ahd      660 non-null    int64
# ...

# %%
relief['SV%'] = relief['SV%'].str.extract('(\d+)%').astype('int') / 100
relief['IS%'] = relief['IS%'].str.extract('(\d+)%').astype('int') / 100

# %%
relief = relief.loc[relief.Year != 2020, ]
relief
# Out:
#      Year                    Tm    G   GR   GF  Wgr  Lgr  SVOpp  SV  BSv  ...  \
# 0    2000        Anaheim Angels  162  441  157   29   24     68  46   22  ...
# 1    2000  Arizona Diamondbacks  162  390  146   23   24     56  38   18  ...
# 2    2000        Atlanta Braves  162  376  149   19   18     67  53   14  ...
# 3    2000     Baltimore Orioles  162  396  148   22   21     57  33   24  ...
# 4    2000        Boston Red Sox  162  425  155   29   23     66  46   20  ...
# ..    ...                   ...  ...  ...  ...  ...  ...    ...  ..  ...  ...
# 655  2021   St. Louis Cardinals  162  557  159   36   25     71  50   21  ...
# 656  2021        Tampa Bay Rays  162  531  161   58   32     64  42   22  ...
# 657  2021         Texas Rangers  162  507  162   27   31     51  31   20  ...
# 658  2021     Toronto Blue Jays  162  537  161   30   31     52  34   18  ...
# 659  2021  Washington Nationals  162  569  161   23   42     73  36   37  ...
#
# ...

# %%
MLrelief = relief.drop(['Year', 'Tm', 'G'], axis = 1)

# %%
MLrelief.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 630 entries, 0 to 659
# Data columns (total 29 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   GR       630 non-null    int64
#  1   GF       630 non-null    int64
#  2   Wgr      630 non-null    int64
#  3   Lgr      630 non-null    int64
#  4   SVOpp    630 non-null    int64
#  5   SV       630 non-null    int64
#  6   BSv      630 non-null    int64
#  7   SV%      630 non-null    float64
#  8   SVSit    630 non-null    int64
#  9   Hold     630 non-null    int64
#  10  IR       630 non-null    int64
#  11  IS       630 non-null    int64
#  12  IS%      630 non-null    float64
#  13  aLI      630 non-null    float64
#  14  LevHi    630 non-null    int64
#  15  LevMd    630 non-null    int64
#  16  LevLo    630 non-null    int64
#  17  Ahd      630 non-null    int64
#  18  Tie      630 non-null    int64
#  19  Bhd      630 non-null    int64
#  20  Runr     630 non-null    int64
# ...

# %%
relief.loc[(relief.Playoff == 1) & (relief.Year == 2020), 'Tm']
# Out:
# Series([], Name: Tm, dtype: object)

# %%
relief.to_csv('ReliefPitching_CLEAN.csv', index = False)
MLrelief.to_csv('ReliefPitching_ML.csv', index = False)
